# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data2.csv')


"Information Technology"
"Health Care"
Financials"
Consumer Discretionary"
Communication Services"
Industrial"
Consumer Staples"
Energy"
Utilities"
Real Estate
Materials
# Out:
#   File "/var/folders/8v/x9cjg8bs6vd0s6nvgw9lk7y80000gn/T/ipykernel_11839/3259774353.py", line 5
#     "Health Care
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

# %%
ax.scatter(df.iloc[:,4], df.iloc[:,5], df.iloc[:,6])
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 30}

matplotlib.rc('font', **font)
plt.style.use('Solarize_Light2')

# %%
import random

fig = plt.figure(figsize=(16, 16))
ax = fig.add_subplot(projection='3d')

ax.scatter(df.iloc[:,4], df.iloc[:,5], df.iloc[:,6], s=df.iloc[:,7]*1000, c="#228B22")

# for i in range(len(df)):
#     ax.text(df.iloc[i,4], df.iloc[i,5], df.iloc[i,6], df.iloc[i,0])
    
ax.set_xlabel('Environment', labelpad=40)
ax.set_ylabel('Social', labelpad=40)
ax.set_zlabel('Governance', labelpad=40)
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
